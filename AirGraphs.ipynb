# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dset = pd.read_csv('airdata.csv')
df = pd.DataFrame(dset,columns=['datetime','station_antwerp','station_paris','station_london'])

# %%
df.plot.area(subplots=True)
fig, axs = plt.subplots(figsize=(12, 4))
df.plot.area(ax=axs)
# Out:
# <AxesSubplot:>
